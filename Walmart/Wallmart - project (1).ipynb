# %%
import numpy as np
import pandas as pd

# %%
wallmart=pd.read_csv("F:\\SimpliLearn\\PYTHON\\NISHANT\\Project\\wallmart\\Walmart_Store_sales.csv",encoding="unicode_escape")

# %%
wallmart
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# 5         1  12-03-2010    1439541.59             0        57.79       2.667
# 6         1  19-03-2010    1472515.79             0        54.58       2.720
# 7         1  26-03-2010    1404429.92             0        51.45       2.732
# 8         1  02-04-2010    1594968.28             0        62.27       2.719
# 9         1  09-04-2010    1545418.53             0        65.86       2.770
# 10        1  16-04-2010    1466058.28             0        66.32       2.808
# ...

# %%
wallmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
# Store           6435 non-null int64
# Date            6435 non-null object
# Weekly_Sales    6435 non-null float64
# Holiday_Flag    6435 non-null int64
# Temperature     6435 non-null float64
# Fuel_Price      6435 non-null float64
# CPI             6435 non-null float64
# Unemployment    6435 non-null float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
wallmart.shape
# Out:
# (6435, 8)

# %%
wallmart.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
wallmart.isna().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
wallmart=pd.read_csv("F:\\SimpliLearn\\PYTHON\\NISHANT\\Project\\wallmart\\Walmart_Store_sales.csv",encoding="unicode_escape",parse_dates=["Date"],index_col=["Date"])

# %%
wallmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6435 entries, 2010-05-02 to 2012-10-26
# Data columns (total 7 columns):
# Store           6435 non-null int64
# Weekly_Sales    6435 non-null float64
# Holiday_Flag    6435 non-null int64
# Temperature     6435 non-null float64
# Fuel_Price      6435 non-null float64
# CPI             6435 non-null float64
# Unemployment    6435 non-null float64
# dtypes: float64(5), int64(2)
# memory usage: 402.2 KB

# %%
max_sale=wallmart.groupby('Store').sum()
max_sale
# Out:
#        Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price           CPI  \
# Store
# 1      2.224028e+08            10      9767.87     460.417  30887.555523
# 2      2.753824e+08            10      9754.94     460.417  30837.422420
# 3      5.758674e+07            10     10215.09     460.417  31372.988971
# 4      2.995440e+08            10      8902.23     460.027  18401.192733
# 5      4.547569e+07            10      9925.65     460.417  30968.878137
# 6      2.237561e+08            10      9967.10     460.417  31110.107182
# 7      8.159828e+07            10      5680.00     463.543  27693.986741
# 8      1.299512e+08            10      8939.50     460.417  31379.780750
# 9      7.778922e+07            10      9691.85     460.417  31406.616557
# 10     2.716177e+08            10     10330.49     511.357  18401.192733
# 11     1.939628e+08            10     10364.75     460.417  31372.988971
# 12     1.442872e+08            10     10047.58     515.718  18401.192733
# ...

# %%
max_sale.sort_values(by="Weekly_Sales",ascending=False)
# Out:
#        Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price           CPI  \
# Store
# 20     3.013978e+08            10      7929.55     488.718  29892.452680
# 4      2.995440e+08            10      8902.23     460.027  18401.192733
# 14     2.889999e+08            10      8264.11     488.718  26638.851959
# 13     2.865177e+08            10      7678.69     469.919  18401.192733
# 2      2.753824e+08            10      9754.94     460.417  30837.422420
# 10     2.716177e+08            10     10330.49     511.357  18401.192733
# 27     2.538559e+08            10      8195.49     511.696  19878.613542
# 6      2.237561e+08            10      9967.10     460.417  31110.107182
# 1      2.224028e+08            10      9767.87     460.417  30887.555523
# 39     2.074455e+08            10     10095.42     460.417  30706.256907
# 19     2.066349e+08            10      7478.19     511.696  19318.242848
# 31     1.996139e+08            10      9845.21     460.417  30837.422420
# ...

# %%
#Which store has maximum sales?
#ans: 20 number store has maximum sale of week(20	3.013978e+08	)

# %%
wallmart_std_max=wallmart.groupby('Store').std()
wallmart_std_max
# Out:
#         Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price       CPI  \
# Store
# 1      155980.767761      0.255926    14.250486    0.427313  4.350890
# 2      237683.694682      0.255926    15.492766    0.427313  4.342286
# 3       46319.631557      0.255926    12.645851    0.427313  4.434232
# 4      266201.442297      0.255926    16.180023    0.416967  1.858300
# 5       37737.965745      0.255926    14.225352    0.427313  4.364848
# 6      212525.855862      0.255926    14.146798    0.427313  4.389093
# 7      112585.469220      0.255926    16.565002    0.430022  3.203795
# 8      106280.829881      0.255926    16.024850    0.427313  4.435398
# 9       69028.666585      0.255926    15.614281    0.427313  4.440007
# 10     302262.062504      0.255926    14.031578    0.446957  1.858300
# 11     165833.887863      0.255926    12.604436    0.427313  4.434232
# 12     139166.871880      0.255926    16.630317    0.447926  1.858300
# ...

# %%
wallmart_std_max.sort_values(by="Weekly_Sales",ascending=False)
# Out:
#         Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price       CPI  \
#